# %% [markdown]
# 1. Import the required libraries:

# %%
import pandas as pd
import requests
import json
import math

# %% [markdown]
# 2. Read the data from the CSV or Excel file. In this example, I'm assuming that you have a CSV file named items.csv with columns that match the Item model attributes:

# %%
file_name = 'items.csv'
data = pd.read_csv(file_name)
data.fillna('blank', inplace=True)

# %% [markdown]
# If you have an Excel file instead of a CSV, you can use the read_excel() function:
# ```python
# file_name = 'items.xlsx'
# data = pd.read_excel(file_name)
# ```

# %% [markdown]
# Helper Functions

# %% [markdown]
# 3. Define the API endpoint and a function to post data to the API, here's a generic version
# ```python
# api_endpoint = 'http://localhost:3000/items'
#
# def post_item(item):
#   response = requests.post(api_endpoint, json=item)
#
#   if response.status_code == 201:
#     print(f"Item {item['name']} created successfully.")
#   else:
#     print(f"Error: Failed to create item {item['name']}.")
# ```

# %%
def post_item(item):
    # Replace this URL with the correct URL of your Items API endpoint
    items_api_endpoint = 'http://localhost:3000/items'
    
    response = requests.post(items_api_endpoint, json=item)
    print(f"Item {item} posted to {items_api_endpoint}")
    if response.status_code == 201:
        print(f"Item {item['name']} created successfully.")
    elif response.status_code == 422:
        print(f"Error: Failed to create item {item['name']} - {response.json()}")
    else:
        print(f"Error: Failed to create item {item['name']} - Status code: {response.status_code}")


def process_and_post_items(data):
    for index, row in data.iterrows():
        # Process and adjust the row data to match your model format
        # Map the CSV column names to the correct attribute names in the Item model
        item = {
            'name': row['Name'],
            'alternate_name': row['Alternate Name'],
            'price': json_compliant_float(row['Price']),
            'cost': json_compliant_float(row['Cost']),
            'tax_rate_id': 1,
            'quantity': row['Quantity'],
            'sku': row['SKU']
        }
        item = json.dumps(item)
        # Call the post_item function to post the item to the API
        post_item(json.loads(item))

# Call the process_and_post_items function with the DataFrame
process_and_post_items(data)
# Out:
# Item {'name': 'Swisher', 'alternate_name': 'blank', 'price': 0.99, 'cost': 0.0, 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '87766544'} posted to http://localhost:3000/items
# Error: Failed to create item Swisher - {'tax_rate': ['must exist']}
# Item {'name': 'Swisher Reg', 'alternate_name': 'blank', 'price': 0.99, 'cost': 0.0, 'tax_rate_id': 1, 'quantity': 'blank', 'sku': 'blank'} posted to http://localhost:3000/items
# Error: Failed to create item Swisher Reg - {'tax_rate': ['must exist']}
# Item {'name': 'Regular Vape 10', 'alternate_name': 'blank', 'price': 20.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '02HD8FGZ23608364'} posted to http://localhost:3000/items
# Error: Failed to create item Regular Vape 10 - {'tax_rate': ['must exist']}
# Item {'name': 'Regular  2', 'alternate_name': 'blank', 'price': 14.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665362'} posted to http://localhost:3000/items
# Error: Failed to create item Regular  2 - {'tax_rate': ['must exist']}
# Item {'name': 'La Luna Roja', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '032733702517'} posted to http://localhost:3000/items
# Error: Failed to create item La Luna Roja - {'tax_rate': ['must exist']}
# Item {'name': 'Shangri La La 20cap', 'alternate_name': 'blank', 'price': 11.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '781584830589'} posted to http://localhost:3000/items
# Error: Failed to create item Shangri La La 20cap - {'tax_rate': ['must exist']}
# Item {'name': 'Red Bali 20cap', 'alternate_name': 'blank', 'price': 11.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '781584830619'} posted to http://localhost:3000/items
# Error: Failed to create item Red Bali 20cap - {'tax_rate': ['must exist']}
# Item {'name': 'Texas Red 50cap', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665430'} posted to http://localhost:3000/items
# Error: Failed to create item Texas Red 50cap - {'tax_rate': ['must exist']}
# Item {'name': 'Green Means Go 50cap', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665058'} posted to http://localhost:3000/items
# Error: Failed to create item Green Means Go 50cap - {'tax_rate': ['must exist']}
# Item {'name': 'Great White 50cap', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665447'} posted to http://localhost:3000/items
# Error: Failed to create item Great White 50cap - {'tax_rate': ['must exist']}
# Item {'name': 'Shangri La La 1oz Tea Leaf', 'alternate_name': 'blank', 'price': 11.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665300'} posted to http://localhost:3000/items
# Error: Failed to create item Shangri La La 1oz Tea Leaf - {'tax_rate': ['must exist']}
# Item {'name': 'Green Means Go 1oz Tea Leaf', 'alternate_name': 'blank', 'price': 11.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665027'} posted to http://localhost:3000/items
# Error: Failed to create item Green Means Go 1oz Tea Leaf - {'tax_rate': ['must exist']}
# Item {'name': 'Red Bali 1oz Tea Leaf', 'alternate_name': 'blank', 'price': 11.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665294'} posted to http://localhost:3000/items
# Error: Failed to create item Red Bali 1oz Tea Leaf - {'tax_rate': ['must exist']}
# Item {'name': '1836 Shangrila Lala 4oz', 'alternate_name': 'blank', 'price': 25.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665492'} posted to http://localhost:3000/items
# Error: Failed to create item 1836 Shangrila Lala 4oz - {'tax_rate': ['must exist']}
# Item {'name': 'Green Means Go 40z', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665041'} posted to http://localhost:3000/items
# Error: Failed to create item Green Means Go 40z - {'tax_rate': ['must exist']}
# Item {'name': 'Texas Red 40z', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665089'} posted to http://localhost:3000/items
# Error: Failed to create item Texas Red 40z - {'tax_rate': ['must exist']}
# Item {'name': 'Shangri La La 50ct', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665133'} posted to http://localhost:3000/items
# Error: Failed to create item Shangri La La 50ct - {'tax_rate': ['must exist']}
# Item {'name': 'Peppermint Extract Shot', 'alternate_name': 'blank', 'price': 14.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '600161665423'} posted to http://localhost:3000/items
# Error: Failed to create item Peppermint Extract Shot - {'tax_rate': ['must exist']}
# Item {'name': 'Green Means Go 20ct', 'alternate_name': 'blank', 'price': 11.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '781584830541'} posted to http://localhost:3000/items
# Error: Failed to create item Green Means Go 20ct - {'tax_rate': ['must exist']}
# Item {'name': 'Texas Red 20ct', 'alternate_name': 'blank', 'price': 11.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '781584830558'} posted to http://localhost:3000/items
# Error: Failed to create item Texas Red 20ct - {'tax_rate': ['must exist']}
# Item {'name': 'Regular 3', 'alternate_name': 'blank', 'price': 1.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '031700055687'} posted to http://localhost:3000/items
# Error: Failed to create item Regular 3 - {'tax_rate': ['must exist']}
# Item {'name': 'Watermelon Grape', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '818892019389'} posted to http://localhost:3000/items
# Error: Failed to create item Watermelon Grape - {'tax_rate': ['must exist']}
# Item {'name': 'Green Sweet', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '842426150385'} posted to http://localhost:3000/items
# Error: Failed to create item Green Sweet - {'tax_rate': ['must exist']}
# Item {'name': 'Sweet Delicious', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '818892013486'} posted to http://localhost:3000/items
# Error: Failed to create item Sweet Delicious - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '842426151566'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond - {'tax_rate': ['must exist']}
# Item {'name': 'Blueberry Pineapple', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '818892019235'} posted to http://localhost:3000/items
# Error: Failed to create item Blueberry Pineapple - {'tax_rate': ['must exist']}
# Item {'name': 'Kiwi Berry', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '818892019358'} posted to http://localhost:3000/items
# Error: Failed to create item Kiwi Berry - {'tax_rate': ['must exist']}
# Item {'name': 'Napa Grape', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '818892013493'} posted to http://localhost:3000/items
# Error: Failed to create item Napa Grape - {'tax_rate': ['must exist']}
# Item {'name': 'White Grape', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '818892018511'} posted to http://localhost:3000/items
# Error: Failed to create item White Grape - {'tax_rate': ['must exist']}
# Item {'name': 'Mango', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '818892013516'} posted to http://localhost:3000/items
# Error: Failed to create item Mango - {'tax_rate': ['must exist']}
# Item {'name': 'Raspberry Tea 5ks', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '842426144681'} posted to http://localhost:3000/items
# Error: Failed to create item Raspberry Tea 5ks - {'tax_rate': ['must exist']}
# Item {'name': 'Platinum 5ks', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '842426143936'} posted to http://localhost:3000/items
# Error: Failed to create item Platinum 5ks - {'tax_rate': ['must exist']}
# Item {'name': 'French Vanilla', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '818892013523'} posted to http://localhost:3000/items
# Error: Failed to create item French Vanilla - {'tax_rate': ['must exist']}
# Item {'name': 'EZ Splitz', 'alternate_name': 'blank', 'price': 0.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '8748630049076'} posted to http://localhost:3000/items
# Error: Failed to create item EZ Splitz - {'tax_rate': ['must exist']}
# Item {'name': 'Lighter Leash', 'alternate_name': 'blank', 'price': 2.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '854672000123'} posted to http://localhost:3000/items
# Error: Failed to create item Lighter Leash - {'tax_rate': ['must exist']}
# Item {'name': 'Fly Lid', 'alternate_name': 'blank', 'price': 2.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '658890410500'} posted to http://localhost:3000/items
# Error: Failed to create item Fly Lid - {'tax_rate': ['must exist']}
# Item {'name': 'Odor Trap Bags', 'alternate_name': 'blank', 'price': 6.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '813276024560'} posted to http://localhost:3000/items
# Error: Failed to create item Odor Trap Bags - {'tax_rate': ['must exist']}
# Item {'name': 'Fly Flags', 'alternate_name': 'blank', 'price': 18.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '812624024825'} posted to http://localhost:3000/items
# Error: Failed to create item Fly Flags - {'tax_rate': ['must exist']}
# Item {'name': 'Tile', 'alternate_name': 'blank', 'price': 29.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '819039021128'} posted to http://localhost:3000/items
# Error: Failed to create item Tile - {'tax_rate': ['must exist']}
# Item {'name': 'Bicycle Dice', 'alternate_name': 'blank', 'price': 5.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '073854001066'} posted to http://localhost:3000/items
# Error: Failed to create item Bicycle Dice - {'tax_rate': ['must exist']}
# Item {'name': 'Dab Magic', 'alternate_name': 'blank', 'price': 22.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '647433001602'} posted to http://localhost:3000/items
# Error: Failed to create item Dab Magic - {'tax_rate': ['must exist']}
# Item {'name': 'Silicone Dab Mat', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800868'} posted to http://localhost:3000/items
# Error: Failed to create item Silicone Dab Mat - {'tax_rate': ['must exist']}
# Item {'name': 'Lit Coaster', 'alternate_name': 'blank', 'price': 16.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '783275731762'} posted to http://localhost:3000/items
# Error: Failed to create item Lit Coaster - {'tax_rate': ['must exist']}
# Item {'name': 'Pixel Drop socks', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '611851883966'} posted to http://localhost:3000/items
# Error: Failed to create item Pixel Drop socks - {'tax_rate': ['must exist']}
# Item {'name': 'Boveda', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '850661003502'} posted to http://localhost:3000/items
# Error: Failed to create item Boveda - {'tax_rate': ['must exist']}
# Item {'name': 'Legal Lean Blue Rasdpberry', 'alternate_name': 'blank', 'price': 10.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '704078783147'} posted to http://localhost:3000/items
# Error: Failed to create item Legal Lean Blue Rasdpberry - {'tax_rate': ['must exist']}
# Item {'name': 'Legal Lean Syrup', 'alternate_name': 'blank', 'price': 10.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '088956147369'} posted to http://localhost:3000/items
# Error: Failed to create item Legal Lean Syrup - {'tax_rate': ['must exist']}
# Item {'name': 'Legal Lean Quali', 'alternate_name': 'blank', 'price': 10.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '789156954046'} posted to http://localhost:3000/items
# Error: Failed to create item Legal Lean Quali - {'tax_rate': ['must exist']}
# Item {'name': 'Cigarette Case', 'alternate_name': 'blank', 'price': 6.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '018505124664'} posted to http://localhost:3000/items
# Error: Failed to create item Cigarette Case - {'tax_rate': ['must exist']}
# Item {'name': 'Zee Selfi Stick', 'alternate_name': 'blank', 'price': 14.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840002541855'} posted to http://localhost:3000/items
# Error: Failed to create item Zee Selfi Stick - {'tax_rate': ['must exist']}
# Item {'name': 'Table Tennis Balls', 'alternate_name': 'blank', 'price': 7.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '827680340543'} posted to http://localhost:3000/items
# Error: Failed to create item Table Tennis Balls - {'tax_rate': ['must exist']}
# Item {'name': 'Beer Pong', 'alternate_name': 'blank', 'price': 7.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '766150126822'} posted to http://localhost:3000/items
# Error: Failed to create item Beer Pong - {'tax_rate': ['must exist']}
# Item {'name': 'Lip Balm', 'alternate_name': 'blank', 'price': 1.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '672813038190'} posted to http://localhost:3000/items
# Error: Failed to create item Lip Balm - {'tax_rate': ['must exist']}
# Item {'name': 'Luxe Lashes Dare To Dream', 'alternate_name': 'blank', 'price': 6.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '602989883126'} posted to http://localhost:3000/items
# Error: Failed to create item Luxe Lashes Dare To Dream - {'tax_rate': ['must exist']}
# Item {'name': 'Luxe Lashes Sacrifice', 'alternate_name': 'blank', 'price': 6.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '850018210775'} posted to http://localhost:3000/items
# Error: Failed to create item Luxe Lashes Sacrifice - {'tax_rate': ['must exist']}
# Item {'name': 'Luxe Lashes Excellence', 'alternate_name': 'blank', 'price': 6.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '602989883133'} posted to http://localhost:3000/items
# Error: Failed to create item Luxe Lashes Excellence - {'tax_rate': ['must exist']}
# Item {'name': 'Luxe Lashes', 'alternate_name': 'blank', 'price': 6.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '602989883089'} posted to http://localhost:3000/items
# Error: Failed to create item Luxe Lashes - {'tax_rate': ['must exist']}
# Item {'name': 'Little Trees New Car Scent', 'alternate_name': 'blank', 'price': 1.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '076171101891'} posted to http://localhost:3000/items
# Error: Failed to create item Little Trees New Car Scent - {'tax_rate': ['must exist']}
# Item {'name': 'Little Tree Black Ice', 'alternate_name': 'blank', 'price': 1.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '076171101556'} posted to http://localhost:3000/items
# Error: Failed to create item Little Tree Black Ice - {'tax_rate': ['must exist']}
# Item {'name': 'Magnet Dart Board', 'alternate_name': 'blank', 'price': 19.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '2100000074785'} posted to http://localhost:3000/items
# Error: Failed to create item Magnet Dart Board - {'tax_rate': ['must exist']}
# Item {'name': 'Dominoes', 'alternate_name': 'blank', 'price': 19.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '704551415626'} posted to http://localhost:3000/items
# Error: Failed to create item Dominoes - {'tax_rate': ['must exist']}
# Item {'name': "Texas Hold'em Poker Set", 'alternate_name': 'blank', 'price': 22.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '663054100159'} posted to http://localhost:3000/items
# Error: Failed to create item Texas Hold'em Poker Set - {'tax_rate': ['must exist']}
# Item {'name': 'Dab Rite Digital Thermometer', 'alternate_name': 'blank', 'price': 330.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '860004339304'} posted to http://localhost:3000/items
# Error: Failed to create item Dab Rite Digital Thermometer - {'tax_rate': ['must exist']}
# Item {'name': 'Reclaim It', 'alternate_name': 'blank', 'price': 12.49, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '819436017649'} posted to http://localhost:3000/items
# Error: Failed to create item Reclaim It - {'tax_rate': ['must exist']}
# Item {'name': 'Ww Headsets', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '862897100023'} posted to http://localhost:3000/items
# Error: Failed to create item Ww Headsets - {'tax_rate': ['must exist']}
# Item {'name': 'XG Pods', 'alternate_name': 'blank', 'price': 35.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '852698006518'} posted to http://localhost:3000/items
# Error: Failed to create item XG Pods - {'tax_rate': ['must exist']}
# Item {'name': 'IPhone Headset', 'alternate_name': 'blank', 'price': 10.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '794660600969'} posted to http://localhost:3000/items
# Error: Failed to create item IPhone Headset - {'tax_rate': ['must exist']}
# Item {'name': 'Raw Snapback', 'alternate_name': 'blank', 'price': 40.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '716165154808'} posted to http://localhost:3000/items
# Error: Failed to create item Raw Snapback - {'tax_rate': ['must exist']}
# Item {'name': 'Backwood Cigar Roller', 'alternate_name': 'blank', 'price': 8.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '756779488050'} posted to http://localhost:3000/items
# Error: Failed to create item Backwood Cigar Roller - {'tax_rate': ['must exist']}
# Item {'name': 'Dime Bags', 'alternate_name': 'blank', 'price': 45.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '811926026278'} posted to http://localhost:3000/items
# Error: Failed to create item Dime Bags - {'tax_rate': ['must exist']}
# Item {'name': 'UX 20 Earphones', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '099854982969'} posted to http://localhost:3000/items
# Error: Failed to create item UX 20 Earphones - {'tax_rate': ['must exist']}
# Item {'name': 'U Mini', 'alternate_name': 'blank', 'price': 15.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '099854978559'} posted to http://localhost:3000/items
# Error: Failed to create item U Mini - {'tax_rate': ['must exist']}
# Item {'name': 'Skull Candy Headlining', 'alternate_name': 'blank', 'price': 19.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '878615098084'} posted to http://localhost:3000/items
# Error: Failed to create item Skull Candy Headlining - {'tax_rate': ['must exist']}
# Item {'name': 'Bytech type C', 'alternate_name': 'blank', 'price': 14.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '805112048663'} posted to http://localhost:3000/items
# Error: Failed to create item Bytech type C - {'tax_rate': ['must exist']}
# Item {'name': 'Temper Glass', 'alternate_name': 'blank', 'price': 19.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '810032994709'} posted to http://localhost:3000/items
# Error: Failed to create item Temper Glass - {'tax_rate': ['must exist']}
# Item {'name': 'Inspector 420', 'alternate_name': 'blank', 'price': 'blank', 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': 'blank'} posted to http://localhost:3000/items
# Error: Failed to create item Inspector 420 - {'tax_rate': ['must exist']}
# Item {'name': 'Butt Bucket', 'alternate_name': 'blank', 'price': 10.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '2020018000029'} posted to http://localhost:3000/items
# Error: Failed to create item Butt Bucket - {'tax_rate': ['must exist']}
# Item {'name': 'Chore Boy', 'alternate_name': 'blank', 'price': 4.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '811435002145'} posted to http://localhost:3000/items
# Error: Failed to create item Chore Boy - {'tax_rate': ['must exist']}
# Item {'name': 'Smoke Buddy Jr', 'alternate_name': 'blank', 'price': 16.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '651277420024'} posted to http://localhost:3000/items
# Error: Failed to create item Smoke Buddy Jr - {'tax_rate': ['must exist']}
# Item {'name': 'Foil Puncher', 'alternate_name': 'blank', 'price': 2.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '813276029244'} posted to http://localhost:3000/items
# Error: Failed to create item Foil Puncher - {'tax_rate': ['must exist']}
# Item {'name': 'Smoke Buddy Mega', 'alternate_name': 'blank', 'price': 46.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '651277042028'} posted to http://localhost:3000/items
# Error: Failed to create item Smoke Buddy Mega - {'tax_rate': ['must exist']}
# Item {'name': 'Coco Nara 10 Tablets Charcoal', 'alternate_name': 'blank', 'price': 4.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '819291012285'} posted to http://localhost:3000/items
# Error: Failed to create item Coco Nara 10 Tablets Charcoal - {'tax_rate': ['must exist']}
# Item {'name': 'Star Light 10 Tablet Charcoal', 'alternate_name': 'blank', 'price': 4.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '683964900410'} posted to http://localhost:3000/items
# Error: Failed to create item Star Light 10 Tablet Charcoal - {'tax_rate': ['must exist']}
# Item {'name': '3 Kings Charcoal', 'alternate_name': 'blank', 'price': 3.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '8716294331004'} posted to http://localhost:3000/items
# Error: Failed to create item 3 Kings Charcoal - {'tax_rate': ['must exist']}
# Item {'name': 'Hookah Foil 100sheet 12*12*20', 'alternate_name': 'blank', 'price': 3.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '643690615262'} posted to http://localhost:3000/items
# Error: Failed to create item Hookah Foil 100sheet 12*12*20 - {'tax_rate': ['must exist']}
# Item {'name': "Ata'a Foil", 'alternate_name': 'blank', 'price': 4.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '6224008216346'} posted to http://localhost:3000/items
# Error: Failed to create item Ata'a Foil - {'tax_rate': ['must exist']}
# Item {'name': 'BYO Foil 6"', 'alternate_name': 'blank', 'price': 4.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '848146017014'} posted to http://localhost:3000/items
# Error: Failed to create item BYO Foil 6" - {'tax_rate': ['must exist']}
# Item {'name': 'Elite Foil', 'alternate_name': 'blank', 'price': 4.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '813276025246'} posted to http://localhost:3000/items
# Error: Failed to create item Elite Foil - {'tax_rate': ['must exist']}
# Item {'name': 'BYO Charcoal Burner 1', 'alternate_name': 'blank', 'price': 25.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '848146015935'} posted to http://localhost:3000/items
# Error: Failed to create item BYO Charcoal Burner 1 - {'tax_rate': ['must exist']}
# Item {'name': 'BYO Charcoal Burner', 'alternate_name': 'blank', 'price': 34.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '848146017724'} posted to http://localhost:3000/items
# Error: Failed to create item BYO Charcoal Burner - {'tax_rate': ['must exist']}
# Item {'name': 'Coco Nara 120pc', 'alternate_name': 'blank', 'price': 20.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '5287000553124'} posted to http://localhost:3000/items
# Error: Failed to create item Coco Nara 120pc - {'tax_rate': ['must exist']}
# Item {'name': 'Coco Nara 20pc', 'alternate_name': 'blank', 'price': 5.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '5287000553100'} posted to http://localhost:3000/items
# Error: Failed to create item Coco Nara 20pc - {'tax_rate': ['must exist']}
# Item {'name': 'Coco Blaze 72pc', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '860002088952'} posted to http://localhost:3000/items
# Error: Failed to create item Coco Blaze 72pc - {'tax_rate': ['must exist']}
# Item {'name': 'Titanium 72pc', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '881314515998'} posted to http://localhost:3000/items
# Error: Failed to create item Titanium 72pc - {'tax_rate': ['must exist']}
# Item {'name': 'Coco Nara 60pc', 'alternate_name': 'blank', 'price': 14.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '5287000553117'} posted to http://localhost:3000/items
# Error: Failed to create item Coco Nara 60pc - {'tax_rate': ['must exist']}
# Item {'name': 'Nu 48pc', 'alternate_name': 'blank', 'price': 14.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '819291018133'} posted to http://localhost:3000/items
# Error: Failed to create item Nu 48pc - {'tax_rate': ['must exist']}
# Item {'name': 'Coco Cube 1kg', 'alternate_name': 'blank', 'price': 14.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '6216576073773'} posted to http://localhost:3000/items
# Error: Failed to create item Coco Cube 1kg - {'tax_rate': ['must exist']}
# Item {'name': 'Nu 96pc', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '819291018126'} posted to http://localhost:3000/items
# Error: Failed to create item Nu 96pc - {'tax_rate': ['must exist']}
# Item {'name': 'Starbuzz Charcoal 10tablets', 'alternate_name': 'blank', 'price': 2.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '847244018459'} posted to http://localhost:3000/items
# Error: Failed to create item Starbuzz Charcoal 10tablets - {'tax_rate': ['must exist']}
# Item {'name': 'Hemp Wood OG', 'alternate_name': 'blank', 'price': 1.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '59987796'} posted to http://localhost:3000/items
# Error: Failed to create item Hemp Wood OG - {'tax_rate': ['must exist']}
# Item {'name': 'Hemp Wood Russian Cream', 'alternate_name': 'blank', 'price': 1.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '50387793'} posted to http://localhost:3000/items
# Error: Failed to create item Hemp Wood Russian Cream - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Blueberry', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '19999371'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Blueberry - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Vanilla', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '19829371'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Vanilla - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Choco', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '19869377'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Choco - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Watermelon', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '19889399'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Watermelon - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Mango', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '11319375'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Mango - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Grape', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '19889375'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Grape - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Peach', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '850030268389'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Peach - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Guava', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '850030268419'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Guava - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Russian Cream', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '850030268426'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Russian Cream - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Green Apple', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '850030268396'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Green Apple - {'tax_rate': ['must exist']}
# Item {'name': 'Camo Honey', 'alternate_name': 'blank', 'price': 1.59, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '850030268402'} posted to http://localhost:3000/items
# Error: Failed to create item Camo Honey - {'tax_rate': ['must exist']}
# Item {'name': 'Box Cool Mint', 'alternate_name': 'blank', 'price': 20.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189903392'} posted to http://localhost:3000/items
# Error: Failed to create item Box Cool Mint - {'tax_rate': ['must exist']}
# Item {'name': 'Box Energy Drinks', 'alternate_name': 'blank', 'price': 20.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189903262'} posted to http://localhost:3000/items
# Error: Failed to create item Box Energy Drinks - {'tax_rate': ['must exist']}
# Item {'name': 'Box Cool Lemon', 'alternate_name': 'blank', 'price': 20.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189903422'} posted to http://localhost:3000/items
# Error: Failed to create item Box Cool Lemon - {'tax_rate': ['must exist']}
# Item {'name': 'Box Watermelon Ice', 'alternate_name': 'blank', 'price': 20.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189903439'} posted to http://localhost:3000/items
# Error: Failed to create item Box Watermelon Ice - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Banana Ice', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835003299'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Banana Ice - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Peach Mango', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904658'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Peach Mango - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Mango Strawberry', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189905259'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Mango Strawberry - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Cool Mint', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189905198'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Cool Mint - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Mango', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189905150'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Mango - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Blueberry Raspberry', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904597'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Blueberry Raspberry - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Green Apple Ice', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904535'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Green Apple Ice - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Red Mojito', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904573'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Red Mojito - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Strawberry Banana', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904634'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Strawberry Banana - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Blueberry Kiwi Ice', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189902142'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Blueberry Kiwi Ice - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Pink Lemonade', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904696'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Pink Lemonade - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Sakura Grape', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904719'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Sakura Grape - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Seize', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835004753'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Seize - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Cranberry Lemonade Ice', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189902210'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Cranberry Lemonade Ice - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Love Story', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835004913'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Love Story - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Cool Mint', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835007549'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Cool Mint - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Peach Lemon Pie', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835007426'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Peach Lemon Pie - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Light Strawberry Mango', 'alternate_name': 'blank', 'price': 10.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835002865'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Light Strawberry Mango - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Triple Shake', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835003886'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Triple Shake - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Raspberry Grapefruit', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835003909'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Raspberry Grapefruit - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Light Shake Shake', 'alternate_name': 'blank', 'price': 10.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835002940'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Light Shake Shake - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Aloe Blackcurrant', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835003947'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Aloe Blackcurrant - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Coconut Grove', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835003848'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Coconut Grove - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Light Strawberry Kiwi', 'alternate_name': 'blank', 'price': 10.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835002933'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Light Strawberry Kiwi - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Guava Shake', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835007570'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Guava Shake - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Sour Apple', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904320'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Sour Apple - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Lemon Apple Ice', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904375'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Lemon Apple Ice - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Strawberry Ice', 'alternate_name': 'blank', 'price': 11.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904337'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Strawberry Ice - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy  Vitamin Water', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835007501'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy  Vitamin Water - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Caramel Popcorn', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835007464'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Caramel Popcorn - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Orange Shake', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835007457'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Orange Shake - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Light Banana Ice', 'alternate_name': 'blank', 'price': 10.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835002957'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Light Banana Ice - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Red Apple', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189904481'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Red Apple - {'tax_rate': ['must exist']}
# Item {'name': 'LUX+ Clear', 'alternate_name': 'blank', 'price': 18.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189900117'} posted to http://localhost:3000/items
# Error: Failed to create item LUX+ Clear - {'tax_rate': ['must exist']}
# Item {'name': 'LUX+ Strawberry Raspberry', 'alternate_name': 'blank', 'price': 18.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189900209'} posted to http://localhost:3000/items
# Error: Failed to create item LUX+ Strawberry Raspberry - {'tax_rate': ['must exist']}
# Item {'name': 'LUX+ Cool Mint', 'alternate_name': 'blank', 'price': 18.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189900094'} posted to http://localhost:3000/items
# Error: Failed to create item LUX+ Cool Mint - {'tax_rate': ['must exist']}
# Item {'name': 'Max Guava Shake', 'alternate_name': 'blank', 'price': 16.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835005057'} posted to http://localhost:3000/items
# Error: Failed to create item Max Guava Shake - {'tax_rate': ['must exist']}
# Item {'name': 'Max Energy Drink', 'alternate_name': 'blank', 'price': 16.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189902630'} posted to http://localhost:3000/items
# Error: Failed to create item Max Energy Drink - {'tax_rate': ['must exist']}
# Item {'name': 'Max Berries Shake', 'alternate_name': 'blank', 'price': 16.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835004951'} posted to http://localhost:3000/items
# Error: Failed to create item Max Berries Shake - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Watermelon Ice', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189905112'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Watermelon Ice - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Mix Berries', 'alternate_name': 'blank', 'price': 11.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835003923'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Mix Berries - {'tax_rate': ['must exist']}
# Item {'name': 'LUX Galaxy Blueberry Kiwi Ice', 'alternate_name': 'blank', 'price': 11.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '193835003954'} posted to http://localhost:3000/items
# Error: Failed to create item LUX Galaxy Blueberry Kiwi Ice - {'tax_rate': ['must exist']}
# Item {'name': 'Diamond Blueberry Ice', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189905211'} posted to http://localhost:3000/items
# Error: Failed to create item Diamond Blueberry Ice - {'tax_rate': ['must exist']}
# Item {'name': 'Bannsna Ice', 'alternate_name': 'blank', 'price': 10.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189905174'} posted to http://localhost:3000/items
# Error: Failed to create item Bannsna Ice - {'tax_rate': ['must exist']}
# Item {'name': 'Box Watermelon Ice 2', 'alternate_name': 'blank', 'price': 21.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '840189911373'} posted to http://localhost:3000/items
# Error: Failed to create item Box Watermelon Ice 2 - {'tax_rate': ['must exist']}
# Item {'name': 'Lavender Chamomile', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '734366020036'} posted to http://localhost:3000/items
# Error: Failed to create item Lavender Chamomile - {'tax_rate': ['must exist']}
# Item {'name': 'Clothesline Fresh', 'alternate_name': 'blank', 'price': 14.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '734366019504'} posted to http://localhost:3000/items
# Error: Failed to create item Clothesline Fresh - {'tax_rate': ['must exist']}
# Item {'name': 'Orange Lemon Splash', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '734366037362'} posted to http://localhost:3000/items
# Error: Failed to create item Orange Lemon Splash - {'tax_rate': ['must exist']}
# Item {'name': 'Falin Leaves', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '734366021484'} posted to http://localhost:3000/items
# Error: Failed to create item Falin Leaves - {'tax_rate': ['must exist']}
# Item {'name': 'Apple Orchard', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '734366038321'} posted to http://localhost:3000/items
# Error: Failed to create item Apple Orchard - {'tax_rate': ['must exist']}
# Item {'name': 'Citrus Island', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '850030268013'} posted to http://localhost:3000/items
# Error: Failed to create item Citrus Island - {'tax_rate': ['must exist']}
# Item {'name': 'Midnight Ice', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '810027353450'} posted to http://localhost:3000/items
# Error: Failed to create item Midnight Ice - {'tax_rate': ['must exist']}
# Item {'name': "Fresh Like Baby's Behind", 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '810027356970'} posted to http://localhost:3000/items
# Error: Failed to create item Fresh Like Baby's Behind - {'tax_rate': ['must exist']}
# Item {'name': 'Ozium', 'alternate_name': 'blank', 'price': 3.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '812421030579'} posted to http://localhost:3000/items
# Error: Failed to create item Ozium - {'tax_rate': ['must exist']}
# Item {'name': 'Herbal Infuser', 'alternate_name': 'blank', 'price': 69.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '810008091227'} posted to http://localhost:3000/items
# Error: Failed to create item Herbal Infuser - {'tax_rate': ['must exist']}
# Item {'name': 'Blunt Effects', 'alternate_name': 'blank', 'price': 4.49, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '700786110008'} posted to http://localhost:3000/items
# Error: Failed to create item Blunt Effects - {'tax_rate': ['must exist']}
# Item {'name': 'Skunk Dr. Infra Red', 'alternate_name': 'blank', 'price': 5.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '859145003359'} posted to http://localhost:3000/items
# Error: Failed to create item Skunk Dr. Infra Red - {'tax_rate': ['must exist']}
# Item {'name': 'Skunk Doc. After Green', 'alternate_name': 'blank', 'price': 5.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '859145003335'} posted to http://localhost:3000/items
# Error: Failed to create item Skunk Doc. After Green - {'tax_rate': ['must exist']}
# Item {'name': 'Skunk Doc. Saffron Rain', 'alternate_name': 'blank', 'price': 5.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '859145003328'} posted to http://localhost:3000/items
# Error: Failed to create item Skunk Doc. Saffron Rain - {'tax_rate': ['must exist']}
# Item {'name': 'Smoke Odor Hippie Love', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '734366021125'} posted to http://localhost:3000/items
# Error: Failed to create item Smoke Odor Hippie Love - {'tax_rate': ['must exist']}
# Item {'name': 'Smoke Odor Orange Lemon', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '734366036938'} posted to http://localhost:3000/items
# ...
# Item {'name': 'Design Grinder', 'alternate_name': 'blank', 'price': 9.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '652369013629'} posted to http://localhost:3000/items
# Error: Failed to create item Design Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Piranha 1.5" Grinder', 'alternate_name': 'blank', 'price': 19.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800218'} posted to http://localhost:3000/items
# Error: Failed to create item Piranha 1.5" Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Piranha 2.2" Grinder', 'alternate_name': 'blank', 'price': 26.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800174'} posted to http://localhost:3000/items
# Error: Failed to create item Piranha 2.2" Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Pirnaha 2" Grinder', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800166'} posted to http://localhost:3000/items
# Error: Failed to create item Pirnaha 2" Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Piranha 2" Grinder 1', 'alternate_name': 'blank', 'price': 24.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800163'} posted to http://localhost:3000/items
# Error: Failed to create item Piranha 2" Grinder 1 - {'tax_rate': ['must exist']}
# Item {'name': 'Piranha 2.5" Grinder', 'alternate_name': 'blank', 'price': 29.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800217'} posted to http://localhost:3000/items
# Error: Failed to create item Piranha 2.5" Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Grinder 071C', 'alternate_name': 'blank', 'price': 14.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '652369010499'} posted to http://localhost:3000/items
# Error: Failed to create item Grinder 071C - {'tax_rate': ['must exist']}
# Item {'name': 'Kannastor Grinder V2', 'alternate_name': 'blank', 'price': 99.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '827190610235'} posted to http://localhost:3000/items
# Error: Failed to create item Kannastor Grinder V2 - {'tax_rate': ['must exist']}
# Item {'name': 'Sick Electric Grinder', 'alternate_name': 'blank', 'price': 49.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '6972104520064'} posted to http://localhost:3000/items
# Error: Failed to create item Sick Electric Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Shred It 2" Grinder W', 'alternate_name': 'blank', 'price': 19.49, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '2100000076925'} posted to http://localhost:3000/items
# Error: Failed to create item Shred It 2" Grinder W - {'tax_rate': ['must exist']}
# Item {'name': 'Shred It Grinder', 'alternate_name': 'blank', 'price': 25.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '2100000076932'} posted to http://localhost:3000/items
# Error: Failed to create item Shred It Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Shred It 1.5" Grinder', 'alternate_name': 'blank', 'price': 12.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '2100000076970'} posted to http://localhost:3000/items
# Error: Failed to create item Shred It 1.5" Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Clean Cut 2.2" Grinder', 'alternate_name': 'blank', 'price': 35.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '810033156403'} posted to http://localhost:3000/items
# Error: Failed to create item Clean Cut 2.2" Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Clean Cut 2.4" Grinder', 'alternate_name': 'blank', 'price': 42.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '810033153051'} posted to http://localhost:3000/items
# Error: Failed to create item Clean Cut 2.4" Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Syndicate Smart Stash', 'alternate_name': 'blank', 'price': 39.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '810033157448'} posted to http://localhost:3000/items
# Error: Failed to create item Syndicate Smart Stash - {'tax_rate': ['must exist']}
# Item {'name': 'Syndicate Smart Stash 1', 'alternate_name': 'blank', 'price': 34.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '810033154164'} posted to http://localhost:3000/items
# Error: Failed to create item Syndicate Smart Stash 1 - {'tax_rate': ['must exist']}
# Item {'name': 'Wooden Style Grinder', 'alternate_name': 'blank', 'price': 16.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800712'} posted to http://localhost:3000/items
# Error: Failed to create item Wooden Style Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Toothless Grinder', 'alternate_name': 'blank', 'price': 16.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800767'} posted to http://localhost:3000/items
# Error: Failed to create item Toothless Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Removable Screen Grinder', 'alternate_name': 'blank', 'price': 18.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800753'} posted to http://localhost:3000/items
# Error: Failed to create item Removable Screen Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Wakit Klr Grinder', 'alternate_name': 'blank', 'price': 65.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '860000773348'} posted to http://localhost:3000/items
# Error: Failed to create item Wakit Klr Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Butt Grinder', 'alternate_name': 'blank', 'price': 17.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800755'} posted to http://localhost:3000/items
# Error: Failed to create item Butt Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Window Grinder', 'alternate_name': 'blank', 'price': 16.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '800766'} posted to http://localhost:3000/items
# Error: Failed to create item Window Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Kannastore 2.2 Grinder Silver', 'alternate_name': 'blank', 'price': 32.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '780742466172'} posted to http://localhost:3000/items
# Error: Failed to create item Kannastore 2.2 Grinder Silver - {'tax_rate': ['must exist']}
# Item {'name': 'Kannastor 2.2 Grinder Black', 'alternate_name': 'blank', 'price': 41.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '827190620425'} posted to http://localhost:3000/items
# Error: Failed to create item Kannastor 2.2 Grinder Black - {'tax_rate': ['must exist']}
# Item {'name': 'Kannastor 2.5 Grinder Rose', 'alternate_name': 'blank', 'price': 50.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '827190620531'} posted to http://localhost:3000/items
# Error: Failed to create item Kannastor 2.5 Grinder Rose - {'tax_rate': ['must exist']}
# Item {'name': 'Kannastor 1.5 Grinder Silver', 'alternate_name': 'blank', 'price': 21.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '827190620012'} posted to http://localhost:3000/items
# Error: Failed to create item Kannastor 1.5 Grinder Silver - {'tax_rate': ['must exist']}
# Item {'name': 'Jay Grinder', 'alternate_name': 'blank', 'price': 30.0, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '628178001690'} posted to http://localhost:3000/items
# Error: Failed to create item Jay Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Jay Grinder 1', 'alternate_name': 'blank', 'price': 'blank', 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '628178001768'} posted to http://localhost:3000/items
# Error: Failed to create item Jay Grinder 1 - {'tax_rate': ['must exist']}
# Item {'name': 'Wakit Electric Grinder', 'alternate_name': 'blank', 'price': 54.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '860000773331'} posted to http://localhost:3000/items
# Error: Failed to create item Wakit Electric Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'LTQ Vapor Electric Grinder', 'alternate_name': 'blank', 'price': 49.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '69713957510968'} posted to http://localhost:3000/items
# Error: Failed to create item LTQ Vapor Electric Grinder - {'tax_rate': ['must exist']}
# Item {'name': 'Big Can Long Cut Wintergreen', 'alternate_name': 'blank', 'price': 15.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '042100024043'} posted to http://localhost:3000/items
# Error: Failed to create item Big Can Long Cut Wintergreen - {'tax_rate': ['must exist']}
# Item {'name': 'Winter Green Long Cut', 'alternate_name': 'blank', 'price': 6.99, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '042100010893'} posted to http://localhost:3000/items
# Error: Failed to create item Winter Green Long Cut - {'tax_rate': ['must exist']}
# Item {'name': 'Long Cut 50c Off', 'alternate_name': 'blank', 'price': 6.49, 'cost': 'blank', 'tax_rate_id': 1, 'quantity': 'blank', 'sku': '042100011135'} posted to http://localhost:3000/items
# Error: Failed to create item Long Cut 50c Off - {'tax_rate': ['must exist']}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 33
#      30         post_item(json.loads(item))
#      32 # Call the process_and_post_items function with the DataFrame
# ---> 33 process_and_post_items(data)
#
# Cell In[62], line 30, in process_and_post_items(data)
#      28 item = json.dumps(item)
#      29 # Call the post_item function to post the item to the API
# ---> 30 post_item(json.loads(item))
#
# Cell In[62], line 5, in post_item(item)
#       1 def post_item(item):
#       2     # Replace this URL with the correct URL of your Items API endpoint
#       3     items_api_endpoint = 'http://localhost:3000/items'
# ----> 5     response = requests.post(items_api_endpoint, json=item)
#       6     print(f"Item {item} posted to {items_api_endpoint}")
#       7     if response.status_code == 201:
#
# File ~/workspace/eshop/venv/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/workspace/eshop/venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/workspace/eshop/venv/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/workspace/eshop/venv/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/workspace/eshop/venv/lib/python3.11/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/workspace/eshop/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/workspace/eshop/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/workspace/eshop/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# 3. Define a function to iterate over the rows in the DataFrame and post each item to the API:
